# %% [raw]
# ---
# title: "Styling Pandas DataFrames with Customized Formatting"
# subtitle: "**Customize your tables with Pandas Styler API**"
# author-title: "Author"
# author: "**Jesús López Monroy** <br> Data Scientist <br>"
# abstract-title: "Abstract"
# abstract: >
#     Pandas Styler API, which provides a convenient way to apply formatting to DataFrames to make them more user-friendly.<br>
# published-title: "Published"
# date: last-modified
# date-format: iso
# toc: true
# toc-title: Contents
# toc-location: right
# page-layout: full
# execute:
#     echo: true
# format:
#     html:
#         page-layout: full
#         embed-resources: true
#         code-fold: show
#         html-math-method: katex
#         theme:
#             light: flatly
# code-line-numbers: false
# code-copy: false
# code-overflow: wrap
# jupyter: python3
# ---

# %% [markdown]
# # Styling Pandas DataFrames with Customized Formatting

# %% [markdown]
# ### Overview

# %% [markdown]
# `Pandas DataFrames` are a powerful tool for **data analysis**. However, they can sometimes be **difficult to read and understand for end users**.
#
# Fortunately, we can use the `Pandas Styler API`, which provides a convenient way to apply **formatting to DataFrames to make them more **user-friendly**.
#
# We can, apply, among other, formatting to:
#
# * Specify the precision of decimal values
# * Use custom formatting strings
# * Hide columns or the index

# %% [markdown]
# ### Environment settings

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating DataFrame A

# %%
# simulated data for widget A
df_a = pd.DataFrame(
    {
        'Month':pd.date_range(
            start = '2012-01-01',
            end = '2022-12-31',
            freq = 'MS'
        ),
        'Quotes':np.random.randint(
            low = 1_000_000,
            high = 2_500_000,
            size = 132
        ),
        'Numbers':np.random.randint(
            low = 300_000,
            high = 500_000,
            size = 132
        ),
        'Amounts':np.random.randint(
            low = 750_000,
            high = 1_250_000,
            size = 132
        )
    }
)
df_a['Product'] = 'A'

# %% [markdown]
# ### Creating DataFrame B

# %%
# simulated data for widget B
df_b = pd.DataFrame(
    {
        'Month':pd.date_range(
            start = '2012-01-01',
            end = '2022-12-31',
            freq = 'MS'
        ),
        'Quotes':np.random.randint(
            low = 100_000,
            high = 800_000,
            size = 132
        ),
        'Numbers':np.random.randint(
            low = 10_000,
            high = 95_000,
            size = 132
        ),
        'Amounts':np.random.randint(
            low = 450_000,
            high = 750_000,
            size = 132
        )
    }
)

df_b['Product'] = 'B'

# %% [markdown]
# ### Concatenating DataFrames

# %%
# put it together & sort
df = pd.concat([df_a,df_b],axis = 0)
df.sort_values(by = 'Month',inplace = True)
df.reset_index(drop = True,inplace = True)

# create calculated columns
# average sale
df['Average sale'] = df['Amounts'] / df['Numbers']

# conversion
df['Product conversion'] = df['Numbers'] / df['Quotes']

# %% [markdown]
# ### DataFrame without Formatting

# %%
# Unformatted dataframe
df
# Out:
#          Month   Quotes  Numbers  Amounts Product  Average sale  \
# 0   2012-01-01  1517405   463861   879669       A      1.896406
# 1   2012-01-01   312213    53595   732032       B     13.658588
# 2   2012-02-01  1317734   346549  1071360       A      3.091511
# 3   2012-02-01   372836    62360   677895       B     10.870670
# 4   2012-03-01  1110066   304083   847156       A      2.785937
# ..         ...      ...      ...      ...     ...           ...
# 259 2022-10-01  1196237   437877   819334       A      1.871151
# 260 2022-11-01   636186    82774   494146       B      5.969821
# 261 2022-11-01  1412773   312461  1136536       A      3.637369
# 262 2022-12-01  2185037   427999  1005904       A      2.350248
# 263 2022-12-01   368570    15166   604187       B     39.838257
#
#      Product conversion
# 0              0.305694
# 1              0.171662
# 2              0.262989
# 3              0.167259
# 4              0.273932
# ..                  ...
# 259            0.366045
# 260            0.130110
# 261            0.221169
# 262            0.195877
# 263            0.041148
#
# [264 rows x 7 columns]

# %% [markdown]
# ### Formatted DataFrame

# %%
# Formatted dataframe
formatted_df = df.head(10).style.format(
        {
        'Month':'{:%b %Y}',
        'Quotes':'{:,.0f}',
        'Numbers':'{:,.0f}',
        'Amounts':'£{:,.0f}',
        'Average sale':'£{:,.2f}',
        'Product conversion':'{:.2%}'
        }
    ).hide(axis='index')

# %%
# Display formatted dataframe
formatted_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_63b3e">
#   <thead>
#     <tr>
#       <th id="T_63b3e_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_63b3e_level0_col1" class="col_heading level0 col1" >Quotes</th>
#       <th id="T_63b3e_level0_col2" class="col_heading level0 col2" >Numbers</th>
#       <th id="T_63b3e_level0_col3" class="col_heading level0 col3" >Amounts</th>
#       <th id="T_63b3e_level0_col4" class="col_heading level0 col4" >Product</th>
#       <th id="T_63b3e_level0_col5" class="col_heading level0 col5" >Average sale</th>
#       <th id="T_63b3e_level0_col6" class="col_heading level0 col6" >Product conversion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_63b3e_row0_col0" class="data row0 col0" >Jan 2012</td>
#       <td id="T_63b3e_row0_col1" class="data row0 col1" >1,517,405</td>
#       <td id="T_63b3e_row0_col2" class="data row0 col2" >463,861</td>
#       <td id="T_63b3e_row0_col3" class="data row0 col3" >£879,669</td>
#       <td id="T_63b3e_row0_col4" class="data row0 col4" >A</td>
#       <td id="T_63b3e_row0_col5" class="data row0 col5" >£1.90</td>
#       <td id="T_63b3e_row0_col6" class="data row0 col6" >30.57%</td>
#     </tr>
#     <tr>
#       <td id="T_63b3e_row1_col0" class="data row1 col0" >Jan 2012</td>
#       <td id="T_63b3e_row1_col1" class="data row1 col1" >312,213</td>
#       <td id="T_63b3e_row1_col2" class="data row1 col2" >53,595</td>
#       <td id="T_63b3e_row1_col3" class="data row1 col3" >£732,032</td>
#       <td id="T_63b3e_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_63b3e_row1_col5" class="data row1 col5" >£13.66</td>
#       <td id="T_63b3e_row1_col6" class="data row1 col6" >17.17%</td>
#     </tr>
#     <tr>
#       <td id="T_63b3e_row2_col0" class="data row2 col0" >Feb 2012</td>
#       <td id="T_63b3e_row2_col1" class="data row2 col1" >1,317,734</td>
#       <td id="T_63b3e_row2_col2" class="data row2 col2" >346,549</td>
#       <td id="T_63b3e_row2_col3" class="data row2 col3" >£1,071,360</td>
#       <td id="T_63b3e_row2_col4" class="data row2 col4" >A</td>
#       <td id="T_63b3e_row2_col5" class="data row2 col5" >£3.09</td>
#       <td id="T_63b3e_row2_col6" class="data row2 col6" >26.30%</td>
#     </tr>
#     <tr>
#       <td id="T_63b3e_row3_col0" class="data row3 col0" >Feb 2012</td>
#       <td id="T_63b3e_row3_col1" class="data row3 col1" >372,836</td>
#       <td id="T_63b3e_row3_col2" class="data row3 col2" >62,360</td>
#       <td id="T_63b3e_row3_col3" class="data row3 col3" >£677,895</td>
#       <td id="T_63b3e_row3_col4" class="data row3 col4" >B</td>
#       <td id="T_63b3e_row3_col5" class="data row3 col5" >£10.87</td>
#       <td id="T_63b3e_row3_col6" class="data row3 col6" >16.73%</td>
#     </tr>
#     <tr>
#       <td id="T_63b3e_row4_col0" class="data row4 col0" >Mar 2012</td>
#       <td id="T_63b3e_row4_col1" class="data row4 col1" >1,110,066</td>
#       <td id="T_63b3e_row4_col2" class="data row4 col2" >304,083</td>
#       <td id="T_63b3e_row4_col3" class="data row4 col3" >£847,156</td>
#       <td id="T_63b3e_row4_col4" class="data row4 col4" >A</td>
#       <td id="T_63b3e_row4_col5" class="data row4 col5" >£2.79</td>
#       <td id="T_63b3e_row4_col6" class="data row4 col6" >27.39%</td>
#     </tr>
#     <tr>
#       <td id="T_63b3e_row5_col0" class="data row5 col0" >Mar 2012</td>
#       <td id="T_63b3e_row5_col1" class="data row5 col1" >707,282</td>
#       <td id="T_63b3e_row5_col2" class="data row5 col2" >46,376</td>
#       <td id="T_63b3e_row5_col3" class="data row5 col3" >£737,246</td>
#       <td id="T_63b3e_row5_col4" class="data row5 col4" >B</td>
#       <td id="T_63b3e_row5_col5" class="data row5 col5" >£15.90</td>
#       <td id="T_63b3e_row5_col6" class="data row5 col6" >6.56%</td>
#     </tr>
#     <tr>
#       <td id="T_63b3e_row6_col0" class="data row6 col0" >Apr 2012</td>
#       <td id="T_63b3e_row6_col1" class="data row6 col1" >1,028,719</td>
#       <td id="T_63b3e_row6_col2" class="data row6 col2" >331,405</td>
#       <td id="T_63b3e_row6_col3" class="data row6 col3" >£1,224,341</td>
#       <td id="T_63b3e_row6_col4" class="data row6 col4" >A</td>
#       <td id="T_63b3e_row6_col5" class="data row6 col5" >£3.69</td>
#       <td id="T_63b3e_row6_col6" class="data row6 col6" >32.22%</td>
#     </tr>
#     <tr>
#       <td id="T_63b3e_row7_col0" class="data row7 col0" >Apr 2012</td>
#       <td id="T_63b3e_row7_col1" class="data row7 col1" >388,918</td>
#       <td id="T_63b3e_row7_col2" class="data row7 col2" >64,974</td>
#       <td id="T_63b3e_row7_col3" class="data row7 col3" >£638,303</td>
#       <td id="T_63b3e_row7_col4" class="data row7 col4" >B</td>
#       <td id="T_63b3e_row7_col5" class="data row7 col5" >£9.82</td>
#       <td id="T_63b3e_row7_col6" class="data row7 col6" >16.71%</td>
#     </tr>
#     <tr>
#       <td id="T_63b3e_row8_col0" class="data row8 col0" >May 2012</td>
#       <td id="T_63b3e_row8_col1" class="data row8 col1" >1,854,568</td>
#       <td id="T_63b3e_row8_col2" class="data row8 col2" >451,450</td>
#       <td id="T_63b3e_row8_col3" class="data row8 col3" >£811,687</td>
#       <td id="T_63b3e_row8_col4" class="data row8 col4" >A</td>
#       <td id="T_63b3e_row8_col5" class="data row8 col5" >£1.80</td>
#       <td id="T_63b3e_row8_col6" class="data row8 col6" >24.34%</td>
#     </tr>
#     <tr>
#       <td id="T_63b3e_row9_col0" class="data row9 col0" >May 2012</td>
#       <td id="T_63b3e_row9_col1" class="data row9 col1" >649,043</td>
#       <td id="T_63b3e_row9_col2" class="data row9 col2" >25,458</td>
#       <td id="T_63b3e_row9_col3" class="data row9 col3" >£645,169</td>
#       <td id="T_63b3e_row9_col4" class="data row9 col4" >B</td>
#       <td id="T_63b3e_row9_col5" class="data row9 col5" >£25.34</td>
#       <td id="T_63b3e_row9_col6" class="data row9 col6" >3.92%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Contact
#
# <!-- Avatar -->
# <img src="./Pictures/profile2.png" alt="me" width="75" height="80">
# <!-- Text with color, font, fontsize and specific size -->
# <p style="color:#323232; font-family: Helevetica; font-size: 20px;">Jesus L. Monroy<br>Economist | Data Scientist</p>
# <!-- Insert url links in logos -->
# <!-- Telegram -->
# <a href="https://t.me/j3suslm" target="_blank" rel="noreferrer"> <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSC8DykewOCqmuAO4hAFQMEYkfL68oELRj0BQ&usqp=CAUsize=16&color=3b3b3b" alt="telegram" width="28" height="20" style="padding-left:8px"/>
# <!-- Twitter -->
# <a href="https://www.twitter.com/sqlalchemist" target="_blank" rel="noreferrer"> <img src="https://toppng.com/public/uploads/preview/twitter-x-new-logo-round-icon-png-11692480241tdbz6jparr.webp?size=16&color=3b3b3b" alt="twitter" width="30" height="22" style="padding-left:8px"/>
# <!-- Github -->
# <a href="https://github.com/SqlAlchemist/My-portfolio" target="_blank" rel="noreferrer"> <img src="https://icongr.am/devicon/github-original.svg?size=16&color=3b3b3b" alt="github" width="30" height="30" style="padding-left:8px"/>
# <!-- Linkedin -->
# <a href="https://www.linkedin.com/in/j3sus-lmonroy" target="_blank" rel="noreferrer"> <img src="https://icongr.am/simple/linkedin.svg?size=16&color=3b3b3b" alt="linkedin" width="30" height="30" style="padding-left:8px"/>
# <!-- Medium -->
# <a href="https://medium.com/@jesus_lmonroy" target="_blank" rel="noreferrer"> <img src="https://cdn1.iconfinder.com/data/icons/social-media-and-logos-12/32/Logo_medium-512.png?size=55&color=3b3b3b" alt="medium" width="30" height="33" style="padding-left:8px"/>
